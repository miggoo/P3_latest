# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
connection_string = "root:password@localhost/clia0918_db"
engine = create_engine(f'mysql://{connection_string}',  pool_size=100, max_overflow=200)
csv_file = "excel_working/cafacsandpopallvars.csv"
p3sql1_df = pd.read_csv(csv_file, sep=',')
p3sql1_df.reset_index()

p3sql1_df.fillna(0)
# Out:
# C:\Users\micha\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        PRVDR_CTGRY_SBTYP_CD  PRVDR_CTGRY_CD       CITY_NAME ACPTBL_POC_SW  \
# 0                         1              22         HAYWARD             N
# 1                         1              22         HAYWARD             N
# 2                         1              22     SAN LEANDRO             N
# 3                         1              22           CHICO             N
# 4                         1              22           CHICO             Y
# 5                         1              22         ANTIOCH             N
# 6                         1              22        RICHMOND             Y
# 7                         1              22          FRESNO             N
# ...

# %%
# alfacs_df = p3sql1_df.loc[p3sql1_df.PRVDR_NUM.str.startswith("01")]

# %%
# alfacs_df.head(3)

# %%
# akfacs_df = p3sql1_df.loc[p3sql1_df.PRVDR_NUM.str.startswith("02")]

# %%
# akfacs_df.head(3)

# %%
# azfacs_df = p3sql1_df.loc[p3sql1_df.PRVDR_NUM.str.startswith("03")]

# %%
# azfacs_df.head(3)

# %%
# azfacs_df = p3sql1_df.loc[p3sql1_df.PRVDR_NUM.str.startswith("03")]

# %%
# azfacs_df.head(3)

# %%
# arfacs_df = p3sql1_df.loc[p3sql1_df.PRVDR_NUM.str.startswith("04")]

# %%
# arfacs_df.head(3)

# %%
cafacs_df = p3sql1_df.loc[p3sql1_df.PRVDR_NUM.str.startswith(("05", "55", "75"))]

# %%
cafacs_df.reset_index()
cafacs_df.fillna(0)
cafacs_df = cafacs_df.apply(pd.to_numeric, errors='coerce')

# %%
p3sql1_df.to_sql("cafacspopan", engine, index=False)

# %%
csv_file1 = "excel_working/healthinssocialhousingpoprace.csv"
cacensus_df = pd.read_csv(csv_file1, sep=',', header=0)
cacensus_df.reset_index()


cacensus_df['Geography'] = cacensus_df['Geography'].str.upper()
cacensus_df.fillna(0)
cacensus_df.iloc[0] = cacensus_df.iloc[0].apply(str)
cacensus_df.fillna(0)
# Out:
#                 Geography Total Civilian Noninstitutionalized Population  \
# 0              CALIFORNIA                                     39046835.0
# 1          ALAMEDA COUNTY                                    1.65454e+06
# 2            ALAMEDA CITY                                          77864
# 3           BERKELEY CITY                                         121870
# 4       CASTRO VALLEY CDP                                          61304
# 5            FREMONT CITY                                         234341
# 6            HAYWARD CITY                                         159560
# 7          LIVERMORE CITY                                          90079
# 8            OAKLAND CITY                                         423307
# 9         PLEASANTON CITY                                          82869
# 10       SAN LEANDRO CITY                                          90331
# 11        UNION CITY CITY                                          75243
# ...

# %%
cacensus_df.iloc[1,1] = 1654543
cacensus_df
# Out:
#                 Geography Total Civilian Noninstitutionalized Population  \
# 0              CALIFORNIA                                     39046835.0
# 1          ALAMEDA COUNTY                                        1654543
# 2            ALAMEDA CITY                                          77864
# 3           BERKELEY CITY                                         121870
# 4       CASTRO VALLEY CDP                                          61304
# 5            FREMONT CITY                                         234341
# 6            HAYWARD CITY                                         159560
# 7          LIVERMORE CITY                                          90079
# 8            OAKLAND CITY                                         423307
# 9         PLEASANTON CITY                                          82869
# 10       SAN LEANDRO CITY                                          90331
# 11        UNION CITY CITY                                          75243
# ...

# %%
p3sql1_df.fillna(0)
p3sql1_df.to_sql("cafacsandpopallvars", engine, index=False)

# %%
cacensus_df.fillna(0)
cacensus_df.reset_index()

# %%
.info()

# %%
cacensus_df.to_sql("cacensusdata2018upper3", engine, index=False)
cacensus2018upper3_df
